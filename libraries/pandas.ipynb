# %% [markdown]
# # Pandas Series

# %% [markdown]
# ### creating Series

# %% [markdown]
# #### There are multiple ways to create a pandas Series:

# %%
import numpy as np 
import pandas as pd

# %%
labels = ['a','b','c']
my_lists = [10,20,30]
arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_lists)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_lists,index = labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# # dataFrame

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creation a Dataframe

# %%
data =  {
    'Name' : ['john', 'Anna', 'peter', 'Linda'],
    'Age' : [28,34,29,42], 
    'City' : ['New York', 'Paris', 'Berlin', 'London'], 
    'Salary' : [65000,70000,62000,85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['john',28,'New York', 650000], 
    ['Anna', 34, 'paris', 70000], 
    ['peter', 29, 'Berlin', 62000], 
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)

# %%
df2
# Out:
#        0   1         2       3
# 0   john  28  New York  650000
# 1   Anna  34     paris   70000
# 2  peter  29    Berlin   62000
# 3  Linda  42    London   85000

# %%
columns = ["Name",'Age',"City","Salary"]
df2 = pd.DataFrame(data_list, columns = columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York  650000
# 1   Anna   34     paris   70000
# 2  peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
headers = ['home','area','price']
location = [
    ['titra','siwan','bihar'],
    ['Nitsh','vikash','deva'],
    [2342333,523423,42343]
]
df3 = pd.DataFrame(location,columns = headers)

# %%
df3
# Out:
#       home    area  price
# 0    titra   siwan  bihar
# 1    Nitsh  vikash   deva
# 2  2342333  523423  42343

# %% [markdown]
# ### Selection and indexing of columns

# %%
df[['Name','Age','City']]
# Out:
#     Name  Age      City
# 0   john   28  New York
# 1   Anna   34     Paris
# 2  peter   29    Berlin
# 3  Linda   42    London

# %%
df['Designation'] = ['manager','assistant','director','clerk']
df
# Out:
#     Name  Age      City  Salary Designation
# 0   john   28  New York   65000     manager
# 1   Anna   34     Paris   70000   assistant
# 2  peter   29    Berlin   62000    director
# 3  Linda   42    London   85000       clerk

# %%
df.drop('Designation', axis = 1)
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ### Selecting a Row

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[0]
# Out:
# Name          john
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df.loc[[0,1,2]]
# Out:
#     Name  Age      City  Salary
# 0   john   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  peter   29    Berlin   62000

# %%
df.iloc[1]
# Out:
# Name       Anna
# Age          34
# City      Paris
# Salary    70000
# Name: 1, dtype: object

# %% [markdown]
# ### Selecting Subsets of Rows and Columns

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %% [markdown]
# ### Conditional Selection

# %%
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary
# 1   Anna   34   paris   70000
# 3  Linda   42  London   85000

# %%
df[(df['Age']>30) & df['City'] == 'London']
# Out:
# Empty DataFrame
# Columns: [Name, Age, City, Salary]
# Index: []

# %% [markdown]
# # Missing Data

# %% [markdown]
# ### Finding Missiong Data
